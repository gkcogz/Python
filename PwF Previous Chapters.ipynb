# %%
def age():
    age = int(input("Enter your age, please: "))
    name_str = input("Enter your name, please: ")
    print("Happy birthday, ", name_str, ".", sep="")
    print("You are", age, "years old.")
    if age > 12 and age < 20:
        print("You are a teenager!")
    else:
        print("You are NOT a teenager!")

def factorial ():
    n = int(input("Enter the value of n: ")) #Prompt user to give a value.
    prod = i = 1 # Stated that prod equals to i, and i to 1.    
    while i <= n: # As long as i lower than or eq. to n.
        prod *= i # Multiply prod by i.
        i += 1 #Increase i by one, till i = n. 
        print("The factorial is: ", prod) #print the statement.

def factorial():
    n = int(input("Enter n (0 to quit): "))
    while n != 0:
        prod = 1
        i = 2
        while i <= n:
            prod *= i
            i += 1
        print("The factorial is ", prod, ".", sep="")
        n = int(input("Enter n (0 to quit): "))
    print("Bye now!")

def tri_num(): #The order of strings is important, the code is run string by string.
    n = int(input("Enter the starting value to get its triangle number: " ))
    i = 2
    prod = 1
    while i <= n:
        prod += i
        i += 1
    print("The triangle number is ", prod, ".", sep="")
    n = int(input("Enter the starting value to get its triangle number: " ))

def tri_num(): #The order of strings is important, the code is run string by string.
    n = int(input("Enter the starting value to get its triangle number: " ))
    while n != 0: #Inequality operator is added, thus the cycle restarts.
        i = 2
        prod = 1
        while i <= n:
            prod += i
            i += 1
        print("The triangle number is ", prod, ".", sep="")
        theorem = n* (n+1)/2
        if theorem == prod:
            print("The theorem is right!")
        n = int(input("Enter the starting value to get its triangle number: " ))
    print("Bye now!")#Without the last string that defines n again, the cycle gets into an infinite loop. 

a=1
b=1
while a<200:
    temp = a
    a = a + b
    b = temp
    print(a, end=" ")
